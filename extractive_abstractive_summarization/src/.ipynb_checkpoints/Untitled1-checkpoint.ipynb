# %%
#process 32195

# %%
import pickle

import numpy as np

trainData=np.load('./train.pkl',allow_pickle=True)
valData=np.load('./valid.pkl',allow_pickle=True)
testData=np.load('./test.pkl',allow_pickle=True)
embedding=np.load('./embedding.pkl',allow_pickle=True)
embedding=embedding.vectors

test_remove=[7421, 10381, 10606, 11367, 13617, 14054, 15613, 15755, 17445]
train_remove=[10318, 13123, 15367, 19945, 22458, 22993, 28541, 32094, 35147, 36770, 43614, 46068, 49182, 53332, 54932, 65569, 68450, 68494, 69867, 70103, 70858]
val_remove=[1147, 7085, 8520, 10125]


from torch.utils.data import Dataset,DataLoader
import numpy as np
import torch
from tensorflow.keras.utils import to_categorical

class TrainData(Dataset):
    def __init__(self,trainData,remove_arr,max_len=300):
        trainX=[]
        trainY=[]
        bound=[]
        padding_idx=trainData.padding
        for idx,i in enumerate(trainData):
            if idx in remove_arr:
                continue
            text=i['text']
            label=i['label']
            
            if(len(text)<max_len):
                text=text+[padding_idx]*(max_len-len(text))
                label=label+[padding_idx]*(max_len-len(label))
            trainX.append(text)
            label=to_categorical(label,num_classes=2)
            trainY.append(label)
            bound.append(i['sent_range'])
        self.trainX=trainX
        self.trainY=trainY
        self.bound=bound
    def __len__(self):
        return len(self.trainX)
    def __getitem__(self,idx):
        if torch.is_tensor(idx):
            idx=idx.tolist()
        
        return np.array(self.trainX[idx],dtype=np.long),np.array(self.trainY[idx],dtype=np.float)
    
    def get_bound(self,idx,batch_size):
        return self.bound[idx*batch_size:(idx+1)*batch_size]
    

    
from rouge_score.rouge_scorer import RougeScorer
from multiprocessing import Pool,cpu_count

def calculate_rouge_score(prediction,target):
    ROUGE_TYPES = ['rouge1', 'rouge2', 'rougeL']
    USE_STEMMER = False


    rouge_scorer = RougeScorer(ROUGE_TYPES, use_stemmer=USE_STEMMER)
    with Pool(cpu_count()) as pool:
        scores = pool.starmap(rouge_scorer.score,
                            [(t, p) for t, p in zip(target, prediction)])

    r1s = np.array([s['rouge1'].fmeasure for s in scores])
    r2s = np.array([s['rouge2'].fmeasure for s in scores])
    rls = np.array([s['rougeL'].fmeasure for s in scores])
    scores = {
        'mean': {
            'rouge-1': r1s.mean(),
            'rouge-2': r2s.mean(),
            'rouge-l': rls.mean()
        },
        'std': {
            'rouge-1': r1s.std(),
            'rouge-2': r2s.std(),
            'rouge-l': rls.std()
        },
    }
    return scores

def predict2sentence(data,pred_arr):
    target=[]
    prediction=[]
    assert len(pred_arr)==len(data)
    for p,j in zip(pred_arr,data):
        target.append(j['summary'])
        sent_bounds = {i: bound for i, bound in enumerate(j['sent_bounds'])}
        predict_sent=''
        for sent_idx in p['predict_sentence_index']:
            start, end = sent_bounds.get(sent_idx, (0, 0))
            predict_sent += j['text'][start:end]
        prediction.append(predict_sent)
    return target,prediction

import json
def load_json_data(file_name):
    data=[]
    with open(file_name,'r') as r:
        line=r.readline()
        while line:
            data.append(json.loads(line))
            line=r.readline()
    return data
def remove_dead_entry(data):
    tmp=[]
    for index,i in enumerate(data):
        if(i['text']=='\n' or i['text']==''):
            tmp.append(index)
            
    for index in sorted(tmp, reverse=True):
        del data[index]
    print('remove entry:',tmp)
    return data
def write_revise_data(data,file_name):
    with open(file_name,'w') as w:
        for idx,i in enumerate(data):
            if(idx==len(data)-1):
                word=json.dumps(i)
            else:
                word=json.dumps(i)+'\n'
            w.write(word)

# %%
import torch.nn as nn
class ExtractiveSeqTagging(nn.Module):
    def __init__(self,hidden_size,pretrain_embedding,bidirectional=True):
        super(ExtractiveSeqTagging,self).__init__()
        self.hidden_size=hidden_size
        self.bidirectional=bidirectional
        self.embedding=nn.Embedding.from_pretrained(pretrain_embedding)
        self.gru=nn.LSTM(hidden_size,hidden_size,bidirectional=bidirectional)
        if bidirectional==True:
            self.out=nn.Linear(hidden_size*2,2)
    
    def forward(self,x,hidden):
        embedded=self.embedding(x).transpose(0,1)
        out,_=self.gru(embedded,hidden)
        out=self.out(out)
        return out
#     h_0 of shape (num_layers * num_directions, batch, hidden_size): 
    def initHidden(self,batch):
        shape=(1,batch,self.hidden_size)
        if self.bidirectional==True:
            shape=(2,batch,self.hidden_size)
            
        return torch.zeros(shape,device='cuda')
    def predict(self,x,hidden):
        embedded=self.embedding(x).transpose(0,1)
        
        
        out,_=self.gru(embedded,hidden)
        out=self.out(out)
        out=nn.functional.softmax(out,2)
        return out

# %%
revise_testData=load_json_data('../../data/test_revise.jsonl')
revise_trainData=load_json_data('../../data/train_revise.jsonl')
revise_valData=load_json_data('../../data/val_revise.jsonl')

# %%
from torch.utils.data import DataLoader
batch_size=64
extract_train=TrainData(trainData,train_remove)
extract_val=TrainData(valData,val_remove)
trainLoader=DataLoader(extract_train,batch_size=batch_size,num_workers=1)
valLoader=DataLoader(extract_val,batch_size=batch_size,num_workers=1)

# %%
np.argsort([3,5,2])[]
# Out:
# array([2, 0, 1])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import time
data_dim=embedding.shape[1]
hidden_size=data_dim
out_feat=2

num_epoch=50
lr=0.001
pretrain=torch.Tensor(embedding)


model=ExtractiveSeqTagging(hidden_size,pretrain).cuda()
criterion=nn.BCEWithLogitsLoss(pos_weight=torch.Tensor([11.63]).cuda())
optimizer=optim.Adam(params=model.parameters(),lr=lr)
# model=ExtractiveSeqTagging(30rameters(),lr=lr)
loss=0
best_acc=0


fo = open("loss_train_adl_64_LSTMHID_1.txt", "w")

for epoch in range(1,num_epoch+1):
    epoch_start_time = time.time()
    train_loss=0
    val_loss=0
    pred_arr=[]
    cnt_train=0
    cnt_val=0
    model.train()
    
    for i,e in enumerate(trainLoader):
        hidden=model.initHidden(e[0].shape[0])
        optimizer.zero_grad()
        out=model(e[0].cuda(),(hidden,hidden))
        loss=criterion(out.transpose(0,1),e[1].cuda())
        loss.backward()
        optimizer.step()
        train_loss+=loss.item()
        
        result=np.argmax(out.detach().cpu(),2).T.numpy()
        batch_bounds=extract_train.get_bound(i,batch_size)
        for num,bounds in enumerate(batch_bounds):            
            prediction={}
            candidate=[]
            values=[]
            for num2,j in enumerate(bounds):
                sentence_cnt=np.sum(result[num,:][j[0]:j[1]])
                if(sentence_cnt>0):
                    candidate.append(num2)
                    values.append(sentence_cnt)
            values=np.array(values)
            candidate=np.array(candidate)
            prediction['id']=trainData[cnt_train]['id']
            
            #post processing 設定 threshold
            prediction['predict_sentence_index']=[candidate[i] for i in np.argsort(-values)]
            
            cnt_train+=1
            pred_arr.append(prediction)
        progress = ('#' * int(float(i)/len(trainLoader)*40)).ljust(40)
        print('[%03d|%03d] %2.2f sec(s) | %s |' %(epoch,num_epoch,time.time()-epoch_start_time,progress),end='\r',flush=True)
    target_word,prediction_word=predict2sentence(revise_trainData,pred_arr)
    scores_train=calculate_rouge_score(prediction_word,target_word)
    
    pred_arr=[]
    model.eval()
    with torch.no_grad():
        for i,e in enumerate(valLoader):

            hidden=model.initHidden(e[0].shape[0])
            out=model(e[0].cuda(),(hidden,hidden))
            loss=criterion(out.transpose(0,1),e[1].cuda())
            val_loss+=loss.item()
            
            result=np.argmax(out.detach().cpu(),2).T.numpy()
        
            batch_bounds=extract_val.get_bound(i,batch_size)
            
            for num,bounds in enumerate(batch_bounds):            
                prediction={}
                candidate=[]
                values=[]
                for num2,j in enumerate(bounds):
                    sentence_cnt=np.sum(result[num,:][j[0]:j[1]])
                    if(sentence_cnt>0):
                        candidate.append(num2)
                        values.append(sentence_cnt)
                prediction['id']=valData[cnt_val]['id']
                
                values=np.array(values)
                candidate=np.array(candidate)
                
                prediction['predict_sentence_index']=[candidate[i] for i in np.argsort(-values)]
                cnt_val+=1
                pred_arr.append(prediction)
                
            progress = ('#' * int(float(i)/len(valLoader)*40)).ljust(40)
            print('[%03d|%03d] %2.2f sec(s) | %s |' %(epoch,num_epoch,time.time()-epoch_start_time,progress),end='\r',flush=True)
    
    target_word,prediction_word=predict2sentence(revise_valData,pred_arr)
    scores_val=calculate_rouge_score(prediction_word,target_word)
    
    fo.write('[%03d|%03d] %2.2f sec(s) | train loss: %2.5f | rouge-1: %2.4f | rouge-2: %2.4f |rouge-l: %2.4f |val loss: %2.5f | rouge-1: %2.4f | rouge-2: %2.4f |rouge-l: %2.4f \n' \
          %(epoch,num_epoch,time.time()-epoch_start_time,train_loss/len(trainLoader.sampler),scores_train['mean']['rouge-1']\
            ,scores_train['mean']['rouge-2'],scores_train['mean']['rouge-l'],val_loss/len(valLoader.sampler),\
            scores_val['mean']['rouge-1'],scores_val['mean']['rouge-2'],scores_val['mean']['rouge-l'] \
            ))
    
    print('[%03d|%03d] %2.2f sec(s) | train loss: %2.5f | rouge-1: %2.4f | rouge-2: %2.4f |rouge-l: %2.4f |val loss: %2.5f | rouge-1: %2.4f | rouge-2: %2.4f |rouge-l: %2.4f' \
          %(epoch,num_epoch,time.time()-epoch_start_time,train_loss/len(trainLoader.sampler),scores_train['mean']['rouge-1']\
            ,scores_train['mean']['rouge-2'],scores_train['mean']['rouge-l'],val_loss/len(valLoader.sampler),\
            scores_val['mean']['rouge-1'],scores_val['mean']['rouge-2'],scores_val['mean']['rouge-l'] \
            ))
    if best_acc<scores_val['mean']['rouge-1']:
        best_acc=scores_val['mean']['rouge-1']
        torch.save(model.state_dict(), './state_dict/model'+str(epoch)+'.pth')
        
fo.close()
# Out:
# [001|050] 142.78 sec(s) | train loss: 0.01482 | rouge-1: 0.0052 | rouge-2: 0.0009 |rouge-l: 0.0038 |val loss: 0.01518 | rouge-1: 0.0157 | rouge-2: 0.0028 |rouge-l: 0.0117
# [002|050] 145.31 sec(s) | train loss: 0.01535 | rouge-1: 0.0196 | rouge-2: 0.0036 |rouge-l: 0.0145 |val loss: 0.01566 | rouge-1: 0.0244 | rouge-2: 0.0045 |rouge-l: 0.0183
# [003|050] 145.29 sec(s) | train loss: 0.01580 | rouge-1: 0.0289 | rouge-2: 0.0051 |rouge-l: 0.0214 |val loss: 0.01599 | rouge-1: 0.0312 | rouge-2: 0.0057 |rouge-l: 0.0233
# [004|050] 22.58 sec(s) | #######                                  |
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [013|050] 149.64 sec(s) | train loss: 0.01852 | rouge-1: 0.2129 | rouge-2: 0.0417 |rouge-l: 0.1481 |val loss: 0.02885 | rouge-1: 0.1790 | rouge-2: 0.0281 |rouge-l: 0.1257
# [014|050] 144.67 sec(s) | train loss: 0.01915 | rouge-1: 0.2203 | rouge-2: 0.0438 |rouge-l: 0.1529 |val loss: 0.03221 | rouge-1: 0.1746 | rouge-2: 0.0270 |rouge-l: 0.1229
# [015|050] 75.70 sec(s) | ########################                 |
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [024|050] 149.97 sec(s) | train loss: 0.02589 | rouge-1: 0.2465 | rouge-2: 0.0518 |rouge-l: 0.1718 |val loss: 0.05433 | rouge-1: 0.1752 | rouge-2: 0.0271 |rouge-l: 0.1232
# [025|050] 149.67 sec(s) | train loss: 0.02643 | rouge-1: 0.2472 | rouge-2: 0.0519 |rouge-l: 0.1723 |val loss: 0.05699 | rouge-1: 0.1759 | rouge-2: 0.0272 |rouge-l: 0.1240
# [026|050] 138.38 sec(s) | ######                                   |
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [036|050] 149.07 sec(s) | train loss: 0.02985 | rouge-1: 0.2532 | rouge-2: 0.0538 |rouge-l: 0.1777 |val loss: 0.06631 | rouge-1: 0.1768 | rouge-2: 0.0270 |rouge-l: 0.1237
# [037|050] 149.36 sec(s) | train loss: 0.03013 | rouge-1: 0.2537 | rouge-2: 0.0541 |rouge-l: 0.1782 |val loss: 0.06666 | rouge-1: 0.1766 | rouge-2: 0.0274 |rouge-l: 0.1237
# [038|050] 29.99 sec(s) | #########                                |
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [047|050] 149.19 sec(s) | train loss: 0.03217 | rouge-1: 0.2550 | rouge-2: 0.0546 |rouge-l: 0.1795 |val loss: 0.06819 | rouge-1: 0.1748 | rouge-2: 0.0268 |rouge-l: 0.1226
# [048|050] 140.71 sec(s) | train loss: 0.03209 | rouge-1: 0.2558 | rouge-2: 0.0548 |rouge-l: 0.1801 |val loss: 0.07069 | rouge-1: 0.1746 | rouge-2: 0.0270 |rouge-l: 0.1227
# [049|050] 45.94 sec(s) | ##############################           |
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
! mkdir state_dict

# %%
from torch.utils.data import DataLoader
batch_size=64
extract_train=TrainData(trainData,train_remove)
extract_val=TrainData(valData,val_remove)
trainLoader=DataLoader(extract_train,batch_size=batch_size,num_workers=1)
valLoader=DataLoader(extract_val,batch_size=batch_size,num_workers=1)

# %%
data_dim=embedding.shape[1]
hidden_size=data_dim

# %%
model=ExtractiveSeqTagging(hidden_size,embedding).cuda()
model.load_state_dict(torch.load('./state_dict/model30.pth'))

model.eval()

pred=[]


for data in valLoader:
    hidden=model.initHidden(data[0].shape[0])
    pred.append(model.predict(data[0].cuda(),(hidden,hidden)).cpu().detach().numpy())

# %%
pred_arr=[]
cnt_val=0
for idx,i in enumerate(pred):
    result=np.argmax(i,2).T
    batch_bounds=extract_val.get_bound(idx,batch_size)
    for num,bounds in enumerate(batch_bounds):            
        prediction={}
        candidate=[]
        values=[]
        for num2,j in enumerate(bounds):
            sentence_cnt=np.sum(result[num,:][j[0]:j[1]])
            if(sentence_cnt>0):
                candidate.append(num2)
                values.append(sentence_cnt)
        values=np.array(values)
        candidate=np.array(candidate)
        prediction['id']=valData[cnt_val]['id']

        #post processing 設定 threshold
        prediction['predict_sentence_index']=[candidate[i] for i in np.argsort(-values)]

        cnt_val+=1
        pred_arr.append(prediction)

# %%
def predict2sentence(data,pred_arr):
    target=[]
    prediction=[]
    assert len(pred_arr)==len(data)
    for p,j in zip(pred_arr,data):
        target.append(j['summary'])
        sent_bounds = {i: bound for i, bound in enumerate(j['sent_bounds'])}
        predict_sent=''
        
        for idx,sent_idx in enumerate(p['predict_sentence_index']):
            start, end = sent_bounds.get(sent_idx, (0, 0))
            predict_sent += j['text'][start:end]
            if(idx==1):
                break
        prediction.append(predict_sent)
    return target,prediction

# %%
target_word,prediction_word=predict2sentence(revise_valData,pred_arr)
scores_train=calculate_rouge_score(prediction_word,target_word)

# %%
pred_arr
# Out:
# [{'id': '2000000', 'predict_sentence_index': [10]},
#  {'id': '2000001', 'predict_sentence_index': [7]},
#  {'id': '2000002', 'predict_sentence_index': [0, 5, 6]},
#  {'id': '2000003', 'predict_sentence_index': [4, 6]},
#  {'id': '2000004', 'predict_sentence_index': [1]},
#  {'id': '2000005', 'predict_sentence_index': [8]},
#  {'id': '2000006', 'predict_sentence_index': [2]},
#  {'id': '2000007', 'predict_sentence_index': [5, 19, 2, 10, 0]},
#  {'id': '2000008', 'predict_sentence_index': [4, 2]},
#  {'id': '2000009', 'predict_sentence_index': [3]},
#  {'id': '2000010', 'predict_sentence_index': [3, 0, 1, 6]},
#  {'id': '2000011', 'predict_sentence_index': [1]},
#  {'id': '2000012', 'predict_sentence_index': [0]},
#  {'id': '2000013', 'predict_sentence_index': [9, 0, 8]},
#  {'id': '2000014', 'predict_sentence_index': [3]},
#  {'id': '2000015', 'predict_sentence_index': [2, 1]},
#  {'id': '2000016', 'predict_sentence_index': [7, 1]},
#  {'id': '2000017', 'predict_sentence_index': [0]},
#  {'id': '2000018', 'predict_sentence_index': [0, 3, 1, 2]},
#  {'id': '2000019', 'predict_sentence_index': [4, 0]},
#  {'id': '2000020', 'predict_sentence_index': []},
#  {'id': '2000021', 'predict_sentence_index': [0, 4]},
#  {'id': '2000022', 'predict_sentence_index': [5, 8, 6]},
#  {'id': '2000023', 'predict_sentence_index': [6]},
#  {'id': '2000024', 'predict_sentence_index': [5, 0]},
#  {'id': '2000025', 'predict_sentence_index': [2, 1]},
#  {'id': '2000026', 'predict_sentence_index': [0]},
#  {'id': '2000027', 'predict_sentence_index': [4, 2]},
#  {'id': '2000028', 'predict_sentence_index': [1, 10, 0, 6]},
#  {'id': '2000029', 'predict_sentence_index': [5, 0]},
#  {'id': '2000030', 'predict_sentence_index': [8, 2, 5]},
#  {'id': '2000031', 'predict_sentence_index': [4, 3]},
#  {'id': '2000032', 'predict_sentence_index': [7, 0]},
#  {'id': '2000033', 'predict_sentence_index': [2, 3, 0]},
#  {'id': '2000034', 'predict_sentence_index': [2, 1]},
#  {'id': '2000035', 'predict_sentence_index': [0, 2]},
#  {'id': '2000036', 'predict_sentence_index': [2, 0]},
#  {'id': '2000037', 'predict_sentence_index': [3, 0]},
#  {'id': '2000038', 'predict_sentence_index': [3, 6, 0]},
#  {'id': '2000039', 'predict_sentence_index': []},
#  {'id': '2000040', 'predict_sentence_index': []},
#  {'id': '2000041', 'predict_sentence_index': [5, 1, 0]},
#  {'id': '2000042', 'predict_sentence_index': [5, 2]},
#  {'id': '2000043', 'predict_sentence_index': [3, 5]},
#  {'id': '2000044', 'predict_sentence_index': [6, 1]},
#  {'id': '2000045', 'predict_sentence_index': [2]},
#  {'id': '2000046', 'predict_sentence_index': [5, 4, 0]},
#  {'id': '2000047', 'predict_sentence_index': [1, 3]},
#  {'id': '2000048', 'predict_sentence_index': [10, 2, 3, 0]},
#  {'id': '2000049', 'predict_sentence_index': [7, 4, 3]},
#  {'id': '2000050', 'predict_sentence_index': [2]},
#  {'id': '2000051', 'predict_sentence_index': [6, 3, 2]},
#  {'id': '2000052', 'predict_sentence_index': [2, 0]},
#  {'id': '2000053', 'predict_sentence_index': [3, 4]},
#  {'id': '2000054', 'predict_sentence_index': [2, 3]},
#  {'id': '2000055', 'predict_sentence_index': [12, 3, 11]},
#  {'id': '2000056', 'predict_sentence_index': [7, 4]},
#  {'id': '2000057', 'predict_sentence_index': [0]},
#  {'id': '2000058', 'predict_sentence_index': [4, 8]},
#  {'id': '2000059', 'predict_sentence_index': [0]},
#  {'id': '2000060', 'predict_sentence_index': [0, 4]},
#  {'id': '2000061', 'predict_sentence_index': [0, 2]},
#  {'id': '2000062', 'predict_sentence_index': [1, 4, 6]},
#  {'id': '2000063', 'predict_sentence_index': [5, 0, 8]},
#  {'id': '2000064', 'predict_sentence_index': [3]},
#  {'id': '2000065', 'predict_sentence_index': [1, 0, 11]},
#  {'id': '2000066', 'predict_sentence_index': [3]},
#  {'id': '2000067', 'predict_sentence_index': [9, 5]},
#  {'id': '2000068', 'predict_sentence_index': [3, 4, 1]},
#  {'id': '2000069', 'predict_sentence_index': [0]},
#  {'id': '2000070', 'predict_sentence_index': [6]},
#  {'id': '2000071', 'predict_sentence_index': [1, 5, 15]},
#  {'id': '2000072', 'predict_sentence_index': [5]},
#  {'id': '2000073', 'predict_sentence_index': [0, 4]},
#  {'id': '2000074', 'predict_sentence_index': [0, 6, 2, 5]},
#  {'id': '2000075', 'predict_sentence_index': [3]},
#  {'id': '2000076', 'predict_sentence_index': [5, 1]},
#  {'id': '2000077', 'predict_sentence_index': [10, 1]},
#  {'id': '2000078', 'predict_sentence_index': [1, 3, 4]},
#  {'id': '2000079', 'predict_sentence_index': [5]},
#  {'id': '2000080', 'predict_sentence_index': [1]},
#  {'id': '2000081', 'predict_sentence_index': [3, 9]},
#  {'id': '2000082', 'predict_sentence_index': [9, 4, 3]},
#  {'id': '2000083', 'predict_sentence_index': [1]},
#  {'id': '2000084', 'predict_sentence_index': []},
#  {'id': '2000085', 'predict_sentence_index': [2]},
#  {'id': '2000086', 'predict_sentence_index': [1, 0, 5]},
#  {'id': '2000087', 'predict_sentence_index': [1]},
#  {'id': '2000088', 'predict_sentence_index': [6]},
#  {'id': '2000089', 'predict_sentence_index': [9]},
#  {'id': '2000090', 'predict_sentence_index': [1, 0]},
#  {'id': '2000091', 'predict_sentence_index': [3, 4]},
#  {'id': '2000092', 'predict_sentence_index': [9, 10]},
#  {'id': '2000093', 'predict_sentence_index': [1]},
#  {'id': '2000094', 'predict_sentence_index': [2, 1]},
#  {'id': '2000095', 'predict_sentence_index': [1, 2]},
#  {'id': '2000096', 'predict_sentence_index': [13, 4]},
#  {'id': '2000097', 'predict_sentence_index': [5]},
#  {'id': '2000098', 'predict_sentence_index': [0, 9, 7, 3]},
#  {'id': '2000099', 'predict_sentence_index': [0, 1, 3]},
#  {'id': '2000100', 'predict_sentence_index': []},
#  {'id': '2000101', 'predict_sentence_index': [4]},
#  {'id': '2000102', 'predict_sentence_index': [1, 2]},
#  {'id': '2000103', 'predict_sentence_index': [4, 2, 3]},
#  {'id': '2000104', 'predict_sentence_index': [5, 1, 3]},
#  {'id': '2000105', 'predict_sentence_index': [2, 4]},
#  {'id': '2000106', 'predict_sentence_index': [3, 0, 2]},
#  {'id': '2000107', 'predict_sentence_index': []},
#  {'id': '2000108', 'predict_sentence_index': [0, 3, 2, 1]},
#  {'id': '2000109', 'predict_sentence_index': [3]},
#  {'id': '2000110', 'predict_sentence_index': [0, 3]},
#  {'id': '2000111', 'predict_sentence_index': [4]},
#  {'id': '2000112', 'predict_sentence_index': [0, 2]},
#  {'id': '2000113', 'predict_sentence_index': [2, 7]},
#  {'id': '2000114', 'predict_sentence_index': [2]},
#  {'id': '2000115', 'predict_sentence_index': [9, 3]},
#  {'id': '2000116', 'predict_sentence_index': [0]},
#  {'id': '2000117', 'predict_sentence_index': [2, 3]},
#  {'id': '2000118', 'predict_sentence_index': [2, 4]},
#  {'id': '2000119', 'predict_sentence_index': [2, 0]},
#  {'id': '2000120', 'predict_sentence_index': [0, 4]},
#  {'id': '2000121', 'predict_sentence_index': [2]},
#  {'id': '2000122', 'predict_sentence_index': [10, 0, 11]},
#  {'id': '2000123', 'predict_sentence_index': [3, 0]},
#  {'id': '2000124', 'predict_sentence_index': [4]},
#  {'id': '2000125', 'predict_sentence_index': [0]},
#  {'id': '2000126', 'predict_sentence_index': [2, 3]},
#  {'id': '2000127', 'predict_sentence_index': [3]},
#  {'id': '2000128', 'predict_sentence_index': [0, 3]},
#  {'id': '2000129', 'predict_sentence_index': [0, 2, 1]},
#  {'id': '2000130', 'predict_sentence_index': [5, 4]},
#  {'id': '2000131', 'predict_sentence_index': [7, 6, 4]},
#  {'id': '2000132', 'predict_sentence_index': [5, 0, 1]},
#  {'id': '2000133', 'predict_sentence_index': [9, 6, 8]},
#  {'id': '2000134', 'predict_sentence_index': [2, 3, 4]},
#  {'id': '2000135', 'predict_sentence_index': [2, 0]},
#  {'id': '2000136', 'predict_sentence_index': [2, 1]},
#  {'id': '2000137', 'predict_sentence_index': [1, 4]},
#  {'id': '2000138', 'predict_sentence_index': [0, 1]},
#  {'id': '2000139', 'predict_sentence_index': []},
#  {'id': '2000140', 'predict_sentence_index': [12]},
#  {'id': '2000141', 'predict_sentence_index': [4]},
#  {'id': '2000142', 'predict_sentence_index': [4, 1]},
#  {'id': '2000143', 'predict_sentence_index': [3, 2]},
#  {'id': '2000144', 'predict_sentence_index': [3]},
#  {'id': '2000145', 'predict_sentence_index': [0, 2]},
#  {'id': '2000146', 'predict_sentence_index': [10, 9]},
#  {'id': '2000147', 'predict_sentence_index': [7]},
#  {'id': '2000148', 'predict_sentence_index': []},
#  {'id': '2000149', 'predict_sentence_index': [3]},
#  {'id': '2000150', 'predict_sentence_index': [1]},
#  {'id': '2000151', 'predict_sentence_index': [1, 0]},
#  {'id': '2000152', 'predict_sentence_index': [2, 4]},
#  {'id': '2000153', 'predict_sentence_index': [0]},
#  {'id': '2000154', 'predict_sentence_index': [0]},
#  {'id': '2000155', 'predict_sentence_index': [0, 4]},
#  {'id': '2000156', 'predict_sentence_index': [0]},
#  {'id': '2000157', 'predict_sentence_index': [4, 10, 2, 3, 6]},
#  {'id': '2000158', 'predict_sentence_index': []},
#  {'id': '2000159', 'predict_sentence_index': [2, 3, 1]},
#  {'id': '2000160', 'predict_sentence_index': [5, 4]},
#  {'id': '2000161', 'predict_sentence_index': [6]},
#  {'id': '2000162', 'predict_sentence_index': [11]},
#  {'id': '2000163', 'predict_sentence_index': [8, 0]},
#  {'id': '2000164', 'predict_sentence_index': [5]},
#  {'id': '2000165', 'predict_sentence_index': [2, 6, 8]},
#  {'id': '2000166', 'predict_sentence_index': [2, 3]},
#  {'id': '2000167', 'predict_sentence_index': [2]},
#  {'id': '2000168', 'predict_sentence_index': [5, 10]},
#  {'id': '2000169', 'predict_sentence_index': [0]},
#  {'id': '2000170', 'predict_sentence_index': [3, 1]},
#  {'id': '2000171', 'predict_sentence_index': [0, 1]},
#  {'id': '2000172', 'predict_sentence_index': [0, 2, 1]},
#  {'id': '2000173', 'predict_sentence_index': [0, 2]},
#  {'id': '2000174', 'predict_sentence_index': [8, 3]},
#  {'id': '2000175', 'predict_sentence_index': [3, 0]},
#  {'id': '2000176', 'predict_sentence_index': [0, 7]},
#  {'id': '2000177', 'predict_sentence_index': [1]},
#  {'id': '2000178', 'predict_sentence_index': [2]},
#  {'id': '2000179', 'predict_sentence_index': [0]},
#  {'id': '2000180', 'predict_sentence_index': [5, 2, 4]},
#  {'id': '2000181', 'predict_sentence_index': [0, 3]},
#  {'id': '2000182', 'predict_sentence_index': [3, 0]},
#  {'id': '2000183', 'predict_sentence_index': [2, 1, 4, 6]},
#  {'id': '2000184', 'predict_sentence_index': [8, 4, 3]},
#  {'id': '2000185', 'predict_sentence_index': [0]},
#  {'id': '2000186', 'predict_sentence_index': [8, 0, 9, 1]},
#  {'id': '2000187', 'predict_sentence_index': [4, 3]},
#  {'id': '2000188', 'predict_sentence_index': [2]},
#  {'id': '2000189', 'predict_sentence_index': [0, 5]},
#  {'id': '2000190', 'predict_sentence_index': [2]},
#  {'id': '2000191', 'predict_sentence_index': [3, 0]},
#  {'id': '2000192', 'predict_sentence_index': [2]},
#  {'id': '2000193', 'predict_sentence_index': [0, 2, 1]},
#  {'id': '2000194', 'predict_sentence_index': [2, 11]},
#  {'id': '2000195', 'predict_sentence_index': [7, 1]},
#  {'id': '2000196', 'predict_sentence_index': [1, 4]},
#  {'id': '2000197', 'predict_sentence_index': [4, 6, 3, 0]},
#  {'id': '2000198', 'predict_sentence_index': [10, 1]},
#  {'id': '2000199', 'predict_sentence_index': [4, 2, 3]},
#  {'id': '2000200', 'predict_sentence_index': [2, 1]},
#  {'id': '2000201', 'predict_sentence_index': [2, 1]},
#  {'id': '2000202', 'predict_sentence_index': [6, 8]},
#  {'id': '2000203', 'predict_sentence_index': [3, 2]},
#  {'id': '2000204', 'predict_sentence_index': [4]},
#  {'id': '2000205', 'predict_sentence_index': [2]},
#  {'id': '2000206', 'predict_sentence_index': []},
#  {'id': '2000207', 'predict_sentence_index': [2, 0, 5]},
#  {'id': '2000208', 'predict_sentence_index': [1]},
#  {'id': '2000209', 'predict_sentence_index': [3, 4]},
#  {'id': '2000210', 'predict_sentence_index': [3, 4]},
#  {'id': '2000211', 'predict_sentence_index': [1, 2]},
#  {'id': '2000212', 'predict_sentence_index': [2, 1]},
#  {'id': '2000213', 'predict_sentence_index': []},
#  {'id': '2000214', 'predict_sentence_index': [4, 3, 6, 0]},
#  {'id': '2000215', 'predict_sentence_index': [4]},
#  {'id': '2000216', 'predict_sentence_index': [4]},
#  {'id': '2000217', 'predict_sentence_index': [5, 0]},
#  {'id': '2000218', 'predict_sentence_index': [9]},
#  {'id': '2000219', 'predict_sentence_index': [5, 3]},
#  {'id': '2000220', 'predict_sentence_index': [0, 2]},
#  {'id': '2000221', 'predict_sentence_index': [4, 3]},
#  {'id': '2000222', 'predict_sentence_index': [0]},
#  {'id': '2000223', 'predict_sentence_index': [0]},
#  {'id': '2000224', 'predict_sentence_index': [1]},
#  {'id': '2000225', 'predict_sentence_index': [3, 2]},
#  {'id': '2000226', 'predict_sentence_index': [0]},
#  {'id': '2000227', 'predict_sentence_index': [9]},
#  {'id': '2000228', 'predict_sentence_index': [3, 4, 6, 2]},
#  {'id': '2000229', 'predict_sentence_index': [0, 1]},
#  {'id': '2000230', 'predict_sentence_index': [3, 2, 1]},
#  {'id': '2000231', 'predict_sentence_index': [2]},
#  {'id': '2000232', 'predict_sentence_index': [5]},
#  {'id': '2000233', 'predict_sentence_index': [1]},
#  {'id': '2000234', 'predict_sentence_index': []},
#  {'id': '2000235', 'predict_sentence_index': [10, 1]},
#  {'id': '2000236', 'predict_sentence_index': [11, 3, 2]},
#  {'id': '2000237', 'predict_sentence_index': [5, 8, 1]},
#  {'id': '2000238', 'predict_sentence_index': [0, 3, 1]},
#  {'id': '2000239', 'predict_sentence_index': [2, 3]},
#  {'id': '2000240', 'predict_sentence_index': [3]},
#  {'id': '2000241', 'predict_sentence_index': [6, 10]},
#  {'id': '2000242', 'predict_sentence_index': [1]},
#  {'id': '2000243', 'predict_sentence_index': [9, 8]},
#  {'id': '2000244', 'predict_sentence_index': [5, 0]},
#  {'id': '2000245', 'predict_sentence_index': [6, 8, 7]},
#  {'id': '2000246', 'predict_sentence_index': [1, 4, 8]},
#  {'id': '2000247', 'predict_sentence_index': [0]},
#  {'id': '2000248', 'predict_sentence_index': [1, 2]},
#  {'id': '2000249', 'predict_sentence_index': [1]},
#  {'id': '2000250', 'predict_sentence_index': [3]},
#  {'id': '2000251', 'predict_sentence_index': [1, 8]},
#  {'id': '2000252', 'predict_sentence_index': [5, 3]},
#  {'id': '2000253', 'predict_sentence_index': [3]},
#  {'id': '2000254', 'predict_sentence_index': [5, 4, 0, 7]},
#  {'id': '2000255', 'predict_sentence_index': [5, 9]},
#  {'id': '2000256', 'predict_sentence_index': [1]},
#  {'id': '2000257', 'predict_sentence_index': [6]},
#  {'id': '2000258', 'predict_sentence_index': [0, 7]},
#  {'id': '2000259', 'predict_sentence_index': []},
#  {'id': '2000260', 'predict_sentence_index': [1, 2]},
#  {'id': '2000261', 'predict_sentence_index': [0, 3, 4]},
#  {'id': '2000262', 'predict_sentence_index': [0, 1]},
#  {'id': '2000263', 'predict_sentence_index': [7, 0, 8, 3, 1]},
#  {'id': '2000264', 'predict_sentence_index': [2]},
#  {'id': '2000265', 'predict_sentence_index': [0]},
#  {'id': '2000266', 'predict_sentence_index': [6]},
#  {'id': '2000267', 'predict_sentence_index': [0, 1]},
#  {'id': '2000268', 'predict_sentence_index': [2, 1]},
#  {'id': '2000269', 'predict_sentence_index': [5]},
#  {'id': '2000270', 'predict_sentence_index': [11]},
#  {'id': '2000271', 'predict_sentence_index': [3, 6]},
#  {'id': '2000272', 'predict_sentence_index': [9]},
#  {'id': '2000273', 'predict_sentence_index': [2, 11]},
#  {'id': '2000274', 'predict_sentence_index': [3, 0]},
#  {'id': '2000275', 'predict_sentence_index': [3]},
#  {'id': '2000276', 'predict_sentence_index': [3, 0]},
#  {'id': '2000277', 'predict_sentence_index': [8, 0, 2]},
#  {'id': '2000278', 'predict_sentence_index': [2]},
#  {'id': '2000279', 'predict_sentence_index': [3, 2, 1]},
#  {'id': '2000280', 'predict_sentence_index': [2]},
#  {'id': '2000281', 'predict_sentence_index': [2, 3]},
#  {'id': '2000282', 'predict_sentence_index': [5, 8]},
#  {'id': '2000283', 'predict_sentence_index': [1, 0]},
#  {'id': '2000284', 'predict_sentence_index': [10, 1]},
#  {'id': '2000285', 'predict_sentence_index': [8]},
#  {'id': '2000286', 'predict_sentence_index': [1]},
#  {'id': '2000287', 'predict_sentence_index': [1]},
#  {'id': '2000288', 'predict_sentence_index': [3, 0]},
#  {'id': '2000289', 'predict_sentence_index': []},
#  {'id': '2000290', 'predict_sentence_index': [5, 2, 3, 0]},
#  {'id': '2000291', 'predict_sentence_index': [4, 5]},
#  {'id': '2000292', 'predict_sentence_index': [0, 2]},
#  {'id': '2000293', 'predict_sentence_index': [5, 0, 8]},
#  {'id': '2000294', 'predict_sentence_index': [1, 0]},
#  {'id': '2000295', 'predict_sentence_index': [4, 3]},
#  {'id': '2000296', 'predict_sentence_index': [8, 1, 3]},
#  {'id': '2000297', 'predict_sentence_index': [2, 1, 0]},
#  {'id': '2000298', 'predict_sentence_index': [3, 2]},
#  {'id': '2000299', 'predict_sentence_index': [4, 0]},
#  {'id': '2000300', 'predict_sentence_index': [3]},
#  {'id': '2000301', 'predict_sentence_index': [2, 1]},
#  {'id': '2000302', 'predict_sentence_index': [1]},
#  {'id': '2000303', 'predict_sentence_index': [2, 0, 10]},
#  {'id': '2000304', 'predict_sentence_index': [3, 6]},
#  {'id': '2000305', 'predict_sentence_index': [0, 3]},
#  {'id': '2000306', 'predict_sentence_index': [4, 3]},
#  {'id': '2000307', 'predict_sentence_index': [0, 2]},
#  {'id': '2000308', 'predict_sentence_index': [0, 3]},
#  {'id': '2000309', 'predict_sentence_index': [3, 0, 7]},
#  {'id': '2000310', 'predict_sentence_index': [6, 8, 3, 9]},
#  {'id': '2000311', 'predict_sentence_index': [1, 0, 2]},
#  {'id': '2000312', 'predict_sentence_index': [2, 1]},
#  {'id': '2000313', 'predict_sentence_index': [6, 3]},
#  {'id': '2000314', 'predict_sentence_index': [5, 7]},
#  {'id': '2000315', 'predict_sentence_index': [3, 0]},
#  {'id': '2000316', 'predict_sentence_index': [5]},
#  {'id': '2000317', 'predict_sentence_index': [0, 11]},
#  {'id': '2000318', 'predict_sentence_index': [3]},
#  {'id': '2000319', 'predict_sentence_index': [1]},
#  {'id': '2000320', 'predict_sentence_index': [0, 10, 7]},
#  {'id': '2000321', 'predict_sentence_index': [1, 0, 3]},
#  {'id': '2000322', 'predict_sentence_index': [1]},
#  {'id': '2000323', 'predict_sentence_index': [4, 5, 7]},
#  {'id': '2000324', 'predict_sentence_index': [2, 0, 6, 8]},
#  {'id': '2000325', 'predict_sentence_index': [2]},
#  {'id': '2000326', 'predict_sentence_index': [0, 1, 2]},
#  {'id': '2000327', 'predict_sentence_index': [2, 1]},
#  {'id': '2000328', 'predict_sentence_index': [4, 1]},
#  {'id': '2000329', 'predict_sentence_index': [6, 3, 7]},
#  {'id': '2000330', 'predict_sentence_index': [2, 3, 0, 4]},
#  {'id': '2000331', 'predict_sentence_index': [2]},
#  {'id': '2000332', 'predict_sentence_index': [1, 0, 7]},
#  {'id': '2000333', 'predict_sentence_index': [1, 0, 4]},
#  {'id': '2000334', 'predict_sentence_index': [2, 8, 1]},
#  {'id': '2000335', 'predict_sentence_index': [1, 3]},
#  {'id': '2000336', 'predict_sentence_index': [0, 2]},
#  {'id': '2000337', 'predict_sentence_index': [2, 5]},
#  {'id': '2000338', 'predict_sentence_index': [6, 3]},
#  {'id': '2000339', 'predict_sentence_index': [6, 0, 7]},
#  {'id': '2000340', 'predict_sentence_index': [3]},
#  {'id': '2000341', 'predict_sentence_index': [3]},
#  {'id': '2000342', 'predict_sentence_index': [3]},
#  {'id': '2000343', 'predict_sentence_index': [1, 10, 11, 2]},
#  {'id': '2000344', 'predict_sentence_index': []},
#  {'id': '2000345', 'predict_sentence_index': [7]},
#  {'id': '2000346', 'predict_sentence_index': [0, 2]},
#  {'id': '2000347', 'predict_sentence_index': [7, 3]},
#  {'id': '2000348', 'predict_sentence_index': [0]},
#  {'id': '2000349', 'predict_sentence_index': [1]},
#  {'id': '2000350', 'predict_sentence_index': [0]},
#  {'id': '2000351', 'predict_sentence_index': [8, 5, 4]},
#  {'id': '2000352', 'predict_sentence_index': [3, 0]},
#  {'id': '2000353', 'predict_sentence_index': [5]},
#  {'id': '2000354', 'predict_sentence_index': [6, 9]},
#  {'id': '2000355', 'predict_sentence_index': [6, 7, 0]},
#  {'id': '2000356', 'predict_sentence_index': [4]},
#  {'id': '2000357', 'predict_sentence_index': [4, 1, 3]},
#  {'id': '2000358', 'predict_sentence_index': [1]},
#  {'id': '2000359', 'predict_sentence_index': [3, 2, 4]},
#  {'id': '2000360', 'predict_sentence_index': [6, 4]},
#  {'id': '2000361', 'predict_sentence_index': [3, 7, 2]},
#  {'id': '2000362', 'predict_sentence_index': [3, 2]},
#  {'id': '2000363', 'predict_sentence_index': [0, 2]},
#  {'id': '2000364', 'predict_sentence_index': [0]},
#  {'id': '2000365', 'predict_sentence_index': []},
#  {'id': '2000366', 'predict_sentence_index': [10, 0]},
#  {'id': '2000367', 'predict_sentence_index': [5, 2]},
#  {'id': '2000368', 'predict_sentence_index': [4, 0]},
#  {'id': '2000369', 'predict_sentence_index': [0]},
#  {'id': '2000370', 'predict_sentence_index': [5]},
#  {'id': '2000371', 'predict_sentence_index': [0]},
#  {'id': '2000372', 'predict_sentence_index': [0]},
#  {'id': '2000373', 'predict_sentence_index': [5, 4, 1]},
#  {'id': '2000374', 'predict_sentence_index': [3, 2, 0]},
#  {'id': '2000375', 'predict_sentence_index': [0]},
#  {'id': '2000376', 'predict_sentence_index': [8, 6]},
#  {'id': '2000377', 'predict_sentence_index': [8]},
#  {'id': '2000378', 'predict_sentence_index': []},
#  {'id': '2000379', 'predict_sentence_index': [5, 6]},
#  {'id': '2000380', 'predict_sentence_index': [3, 8, 6]},
#  {'id': '2000381', 'predict_sentence_index': [3, 4, 2]},
#  {'id': '2000382', 'predict_sentence_index': [1, 2, 4, 3]},
#  {'id': '2000383', 'predict_sentence_index': [3]},
#  {'id': '2000384', 'predict_sentence_index': [1]},
#  {'id': '2000385', 'predict_sentence_index': [5, 3]},
#  {'id': '2000386', 'predict_sentence_index': [2]},
#  {'id': '2000387', 'predict_sentence_index': [6, 0]},
#  {'id': '2000388', 'predict_sentence_index': [2, 0]},
#  {'id': '2000389', 'predict_sentence_index': [4]},
#  {'id': '2000390', 'predict_sentence_index': [3]},
#  {'id': '2000391', 'predict_sentence_index': [3, 2]},
#  {'id': '2000392', 'predict_sentence_index': [5]},
#  {'id': '2000393', 'predict_sentence_index': [1, 0]},
#  {'id': '2000394', 'predict_sentence_index': [3, 1, 2]},
#  {'id': '2000395', 'predict_sentence_index': [1]},
#  {'id': '2000396', 'predict_sentence_index': [2]},
#  {'id': '2000397', 'predict_sentence_index': [2, 3, 4]},
#  {'id': '2000398', 'predict_sentence_index': [6, 1, 7]},
#  {'id': '2000399', 'predict_sentence_index': [2, 3, 1]},
#  {'id': '2000400', 'predict_sentence_index': [5, 7]},
#  {'id': '2000401', 'predict_sentence_index': [0]},
#  {'id': '2000402', 'predict_sentence_index': [2, 3]},
#  {'id': '2000403', 'predict_sentence_index': [1]},
#  {'id': '2000404', 'predict_sentence_index': [2, 0, 1]},
#  {'id': '2000405', 'predict_sentence_index': [2, 0]},
#  {'id': '2000406', 'predict_sentence_index': [7]},
#  {'id': '2000407', 'predict_sentence_index': [4]},
#  {'id': '2000408', 'predict_sentence_index': [4, 5, 6, 0]},
#  {'id': '2000409', 'predict_sentence_index': [4, 8]},
#  {'id': '2000410', 'predict_sentence_index': [4, 6, 2]},
#  {'id': '2000411', 'predict_sentence_index': [4, 5]},
#  {'id': '2000412', 'predict_sentence_index': [6]},
#  {'id': '2000413', 'predict_sentence_index': [0, 7, 1, 3]},
#  {'id': '2000414', 'predict_sentence_index': [1]},
#  {'id': '2000415', 'predict_sentence_index': [0, 4, 6]},
#  {'id': '2000416', 'predict_sentence_index': [4, 2]},
#  {'id': '2000417', 'predict_sentence_index': [8, 4]},
#  {'id': '2000418', 'predict_sentence_index': [4, 2, 0, 5]},
#  {'id': '2000419', 'predict_sentence_index': [2, 4]},
#  {'id': '2000420', 'predict_sentence_index': [5]},
#  {'id': '2000421', 'predict_sentence_index': [4]},
#  {'id': '2000422', 'predict_sentence_index': [8, 1]},
#  {'id': '2000423', 'predict_sentence_index': [2]},
#  {'id': '2000424', 'predict_sentence_index': [4]},
#  {'id': '2000425', 'predict_sentence_index': [5, 7, 9, 0]},
#  {'id': '2000426', 'predict_sentence_index': [2]},
#  {'id': '2000427', 'predict_sentence_index': [0]},
#  {'id': '2000428', 'predict_sentence_index': []},
#  {'id': '2000429', 'predict_sentence_index': [0]},
#  {'id': '2000430', 'predict_sentence_index': [1, 7, 3]},
#  {'id': '2000431', 'predict_sentence_index': [1]},
#  {'id': '2000432', 'predict_sentence_index': []},
#  {'id': '2000433', 'predict_sentence_index': [2, 6, 9]},
#  {'id': '2000434', 'predict_sentence_index': [2]},
#  {'id': '2000435', 'predict_sentence_index': [7, 8, 3, 5]},
#  {'id': '2000436', 'predict_sentence_index': [5, 0, 1]},
#  {'id': '2000437', 'predict_sentence_index': [2]},
#  {'id': '2000438', 'predict_sentence_index': []},
#  {'id': '2000439', 'predict_sentence_index': [3, 4, 5, 0]},
#  {'id': '2000440', 'predict_sentence_index': [5]},
#  {'id': '2000441', 'predict_sentence_index': [11, 0]},
#  {'id': '2000442', 'predict_sentence_index': [7, 5]},
#  {'id': '2000443', 'predict_sentence_index': [2, 0]},
#  {'id': '2000444', 'predict_sentence_index': [1, 2, 3]},
#  {'id': '2000445', 'predict_sentence_index': [6, 1, 0, 5]},
#  {'id': '2000446', 'predict_sentence_index': [2, 1]},
#  {'id': '2000447', 'predict_sentence_index': [7, 0]},
#  {'id': '2000448', 'predict_sentence_index': [6, 1]},
#  {'id': '2000449', 'predict_sentence_index': [5, 0]},
#  {'id': '2000450', 'predict_sentence_index': [3]},
#  {'id': '2000451', 'predict_sentence_index': [0, 1]},
#  {'id': '2000452', 'predict_sentence_index': [6, 2]},
#  {'id': '2000453', 'predict_sentence_index': [6, 7, 2, 3, 9]},
#  {'id': '2000454', 'predict_sentence_index': [6]},
#  {'id': '2000455', 'predict_sentence_index': []},
#  {'id': '2000456', 'predict_sentence_index': [1, 7]},
#  {'id': '2000457', 'predict_sentence_index': [0, 9]},
#  {'id': '2000458', 'predict_sentence_index': [2, 1, 5]},
#  {'id': '2000459', 'predict_sentence_index': [3, 2]},
#  {'id': '2000460', 'predict_sentence_index': []},
#  {'id': '2000461', 'predict_sentence_index': [3, 0]},
#  {'id': '2000462', 'predict_sentence_index': [3]},
#  {'id': '2000463', 'predict_sentence_index': [0, 7, 6, 2, 5]},
#  {'id': '2000464', 'predict_sentence_index': [1, 2]},
#  {'id': '2000465', 'predict_sentence_index': [5, 11, 6]},
#  {'id': '2000466', 'predict_sentence_index': [5, 4]},
#  {'id': '2000467', 'predict_sentence_index': [5, 4]},
#  {'id': '2000468', 'predict_sentence_index': [0, 1]},
#  {'id': '2000469', 'predict_sentence_index': [0]},
#  {'id': '2000470', 'predict_sentence_index': [5, 4]},
#  {'id': '2000471', 'predict_sentence_index': [2, 7, 6]},
#  {'id': '2000472', 'predict_sentence_index': [6, 1, 8]},
#  {'id': '2000473', 'predict_sentence_index': [6, 3, 2]},
#  {'id': '2000474', 'predict_sentence_index': [1]},
#  {'id': '2000475', 'predict_sentence_index': [6, 2]},
#  {'id': '2000476', 'predict_sentence_index': [4, 7]},
#  {'id': '2000477', 'predict_sentence_index': [1]},
#  {'id': '2000478', 'predict_sentence_index': [4]},
#  {'id': '2000479', 'predict_sentence_index': [3, 4]},
#  {'id': '2000480', 'predict_sentence_index': [5]},
#  {'id': '2000481', 'predict_sentence_index': [4, 3]},
#  {'id': '2000482', 'predict_sentence_index': [3]},
#  {'id': '2000483', 'predict_sentence_index': [4, 9]},
#  {'id': '2000484', 'predict_sentence_index': [1, 4]},
#  {'id': '2000485', 'predict_sentence_index': []},
#  {'id': '2000486', 'predict_sentence_index': [1, 2]},
#  {'id': '2000487', 'predict_sentence_index': [3, 0, 4]},
#  {'id': '2000488', 'predict_sentence_index': [7, 1, 3]},
#  {'id': '2000489', 'predict_sentence_index': [5, 1, 2]},
#  {'id': '2000490', 'predict_sentence_index': [2, 6]},
#  {'id': '2000491', 'predict_sentence_index': [0]},
#  {'id': '2000492', 'predict_sentence_index': [2]},
#  {'id': '2000493', 'predict_sentence_index': [3]},
#  {'id': '2000494', 'predict_sentence_index': [1, 7, 0]},
#  {'id': '2000495', 'predict_sentence_index': [7]},
#  {'id': '2000496', 'predict_sentence_index': [1, 2]},
#  {'id': '2000497', 'predict_sentence_index': [3, 1, 0, 4]},
#  {'id': '2000498', 'predict_sentence_index': [8]},
#  {'id': '2000499', 'predict_sentence_index': [8, 3, 9]},
#  {'id': '2000500', 'predict_sentence_index': [2, 4, 1, 3]},
#  {'id': '2000501', 'predict_sentence_index': []},
#  {'id': '2000502', 'predict_sentence_index': [1, 4, 6]},
#  {'id': '2000503', 'predict_sentence_index': [0, 1]},
#  {'id': '2000504', 'predict_sentence_index': [1, 3, 0]},
#  {'id': '2000505', 'predict_sentence_index': [5, 4, 0]},
#  {'id': '2000506', 'predict_sentence_index': [0, 2]},
#  {'id': '2000507', 'predict_sentence_index': [8, 3]},
#  {'id': '2000508', 'predict_sentence_index': [6]},
#  {'id': '2000509', 'predict_sentence_index': [7, 3, 6]},
#  {'id': '2000510', 'predict_sentence_index': [0]},
#  {'id': '2000511', 'predict_sentence_index': [7, 0, 6]},
#  {'id': '2000512', 'predict_sentence_index': [5, 1, 0, 8]},
#  {'id': '2000513', 'predict_sentence_index': [1, 0, 2, 5]},
#  {'id': '2000514', 'predict_sentence_index': []},
#  {'id': '2000515', 'predict_sentence_index': [0, 2]},
#  {'id': '2000516', 'predict_sentence_index': [8, 2]},
#  {'id': '2000517', 'predict_sentence_index': [0]},
#  {'id': '2000518', 'predict_sentence_index': [3, 0, 1]},
#  {'id': '2000519', 'predict_sentence_index': [3, 13]},
#  {'id': '2000520', 'predict_sentence_index': [3, 2, 0]},
#  {'id': '2000521', 'predict_sentence_index': [2]},
#  {'id': '2000522', 'predict_sentence_index': [1, 2]},
#  {'id': '2000523', 'predict_sentence_index': [6, 9, 1]},
#  {'id': '2000524', 'predict_sentence_index': [5, 6, 3]},
#  {'id': '2000525', 'predict_sentence_index': [0, 1, 9]},
#  {'id': '2000526', 'predict_sentence_index': [2]},
#  {'id': '2000527', 'predict_sentence_index': [2, 10]},
#  {'id': '2000528', 'predict_sentence_index': [6, 8]},
#  {'id': '2000529', 'predict_sentence_index': [3, 2]},
#  {'id': '2000530', 'predict_sentence_index': []},
#  {'id': '2000531', 'predict_sentence_index': [7, 3, 2, 5]},
#  {'id': '2000532', 'predict_sentence_index': [2, 3]},
#  {'id': '2000533', 'predict_sentence_index': [3]},
#  {'id': '2000534', 'predict_sentence_index': [2, 8]},
#  {'id': '2000535', 'predict_sentence_index': [1]},
#  {'id': '2000536', 'predict_sentence_index': [11, 8]},
#  {'id': '2000537', 'predict_sentence_index': [10, 0]},
#  {'id': '2000538', 'predict_sentence_index': [4, 6, 7]},
#  {'id': '2000539', 'predict_sentence_index': [0, 3]},
#  {'id': '2000540', 'predict_sentence_index': [0]},
#  {'id': '2000541', 'predict_sentence_index': [8, 6, 5, 9]},
#  {'id': '2000542', 'predict_sentence_index': [4, 6]},
#  {'id': '2000543', 'predict_sentence_index': [2, 1]},
#  {'id': '2000544', 'predict_sentence_index': [3]},
#  {'id': '2000545', 'predict_sentence_index': [8, 4]},
#  {'id': '2000546', 'predict_sentence_index': [1]},
#  {'id': '2000547', 'predict_sentence_index': [2, 9, 8]},
#  {'id': '2000548', 'predict_sentence_index': [1, 0]},
#  {'id': '2000549', 'predict_sentence_index': [3, 5]},
#  {'id': '2000550', 'predict_sentence_index': [13, 8, 10]},
#  {'id': '2000551', 'predict_sentence_index': [0, 5, 9]},
#  {'id': '2000552', 'predict_sentence_index': [2, 0]},
#  {'id': '2000553', 'predict_sentence_index': [3, 1]},
#  {'id': '2000554', 'predict_sentence_index': [5, 2, 1]},
#  {'id': '2000555', 'predict_sentence_index': [0]},
#  {'id': '2000556', 'predict_sentence_index': [7, 5, 0]},
#  {'id': '2000557', 'predict_sentence_index': [2]},
#  {'id': '2000558', 'predict_sentence_index': [1]},
#  {'id': '2000559', 'predict_sentence_index': [2, 3]},
#  {'id': '2000560', 'predict_sentence_index': [0, 7]},
#  {'id': '2000561', 'predict_sentence_index': [0]},
#  {'id': '2000562', 'predict_sentence_index': [1, 0]},
#  {'id': '2000563', 'predict_sentence_index': [0]},
#  {'id': '2000564', 'predict_sentence_index': [3, 1]},
#  {'id': '2000565', 'predict_sentence_index': [6, 0, 4]},
#  {'id': '2000566', 'predict_sentence_index': [3, 7]},
#  {'id': '2000567', 'predict_sentence_index': [1, 0]},
#  {'id': '2000568', 'predict_sentence_index': [3]},
#  {'id': '2000569', 'predict_sentence_index': [3, 2]},
#  {'id': '2000570', 'predict_sentence_index': [5]},
#  {'id': '2000571', 'predict_sentence_index': [1, 0]},
#  {'id': '2000572', 'predict_sentence_index': [1, 5, 7, 0]},
#  {'id': '2000573', 'predict_sentence_index': [1, 3, 0]},
#  {'id': '2000574', 'predict_sentence_index': [4, 1, 2]},
#  {'id': '2000575', 'predict_sentence_index': [3, 1]},
#  {'id': '2000576', 'predict_sentence_index': [1]},
#  {'id': '2000577', 'predict_sentence_index': [2, 1]},
#  {'id': '2000578', 'predict_sentence_index': [3, 2]},
#  {'id': '2000579', 'predict_sentence_index': [3, 4, 0]},
#  {'id': '2000580', 'predict_sentence_index': [0, 2]},
#  {'id': '2000581', 'predict_sentence_index': [2]},
#  {'id': '2000582', 'predict_sentence_index': [5, 2]},
#  {'id': '2000583', 'predict_sentence_index': [1]},
#  {'id': '2000584', 'predict_sentence_index': [3]},
#  {'id': '2000585', 'predict_sentence_index': [4, 0]},
#  {'id': '2000586', 'predict_sentence_index': [4, 2]},
#  {'id': '2000587', 'predict_sentence_index': [5, 3]},
#  {'id': '2000588', 'predict_sentence_index': [2, 4, 1]},
#  {'id': '2000589', 'predict_sentence_index': [4, 2]},
#  {'id': '2000590', 'predict_sentence_index': []},
#  {'id': '2000591', 'predict_sentence_index': [4]},
#  {'id': '2000592', 'predict_sentence_index': [3, 0]},
#  {'id': '2000593', 'predict_sentence_index': [1, 0]},
#  {'id': '2000594', 'predict_sentence_index': [8, 1, 2]},
#  {'id': '2000595', 'predict_sentence_index': [6]},
#  {'id': '2000596', 'predict_sentence_index': [5, 3, 4]},
#  {'id': '2000597', 'predict_sentence_index': [5, 1]},
#  {'id': '2000598', 'predict_sentence_index': [2]},
#  {'id': '2000599', 'predict_sentence_index': [5, 0]},
#  {'id': '2000600', 'predict_sentence_index': [4, 1, 3]},
#  {'id': '2000601', 'predict_sentence_index': []},
#  {'id': '2000602', 'predict_sentence_index': [0, 6]},
#  {'id': '2000603', 'predict_sentence_index': [0, 6, 2]},
#  {'id': '2000604', 'predict_sentence_index': [6, 3, 4]},
#  {'id': '2000605', 'predict_sentence_index': [0, 5]},
#  {'id': '2000606', 'predict_sentence_index': [0, 6, 5]},
#  {'id': '2000607', 'predict_sentence_index': [2, 3]},
#  {'id': '2000608', 'predict_sentence_index': [1, 2]},
#  {'id': '2000609', 'predict_sentence_index': [4]},
#  {'id': '2000610', 'predict_sentence_index': [2]},
#  {'id': '2000611', 'predict_sentence_index': [4, 1]},
#  {'id': '2000612', 'predict_sentence_index': []},
#  {'id': '2000613', 'predict_sentence_index': [1, 0]},
#  {'id': '2000614', 'predict_sentence_index': [3, 4, 1]},
#  {'id': '2000615', 'predict_sentence_index': [3, 8, 0]},
#  {'id': '2000616', 'predict_sentence_index': [1, 2]},
#  {'id': '2000617', 'predict_sentence_index': [2]},
#  {'id': '2000618', 'predict_sentence_index': [4, 1]},
#  {'id': '2000619', 'predict_sentence_index': [1]},
#  {'id': '2000620', 'predict_sentence_index': [3, 0]},
#  {'id': '2000621', 'predict_sentence_index': [0, 7]},
#  {'id': '2000622', 'predict_sentence_index': [1, 6]},
#  {'id': '2000623', 'predict_sentence_index': [2]},
#  {'id': '2000624', 'predict_sentence_index': [4, 8]},
#  {'id': '2000625', 'predict_sentence_index': [1]},
#  {'id': '2000626', 'predict_sentence_index': [0]},
#  {'id': '2000627', 'predict_sentence_index': [7]},
#  {'id': '2000628', 'predict_sentence_index': [6, 5, 7, 1]},
#  {'id': '2000629', 'predict_sentence_index': [4]},
#  {'id': '2000630', 'predict_sentence_index': [2]},
#  {'id': '2000631', 'predict_sentence_index': [4, 6]},
#  {'id': '2000632', 'predict_sentence_index': [8, 9]},
#  {'id': '2000633', 'predict_sentence_index': [1, 6]},
#  {'id': '2000634', 'predict_sentence_index': [9]},
#  {'id': '2000635', 'predict_sentence_index': [2, 7]},
#  {'id': '2000636', 'predict_sentence_index': [8, 9]},
#  {'id': '2000637', 'predict_sentence_index': [8, 3]},
#  {'id': '2000638', 'predict_sentence_index': [0, 3]},
#  {'id': '2000639', 'predict_sentence_index': [0, 2]},
#  {'id': '2000640', 'predict_sentence_index': [1, 0, 3, 9]},
#  {'id': '2000641', 'predict_sentence_index': [0]},
#  {'id': '2000642', 'predict_sentence_index': [8]},
#  {'id': '2000643', 'predict_sentence_index': [3, 4, 2]},
#  {'id': '2000644', 'predict_sentence_index': [1, 3]},
#  {'id': '2000645', 'predict_sentence_index': [7, 8]},
#  {'id': '2000646', 'predict_sentence_index': [4, 0]},
#  {'id': '2000647', 'predict_sentence_index': [0]},
#  {'id': '2000648', 'predict_sentence_index': [7, 8]},
#  {'id': '2000649', 'predict_sentence_index': [0]},
#  {'id': '2000650', 'predict_sentence_index': [3, 10, 4]},
#  {'id': '2000651', 'predict_sentence_index': [0, 3]},
#  {'id': '2000652', 'predict_sentence_index': [5, 6, 4]},
#  {'id': '2000653', 'predict_sentence_index': [6, 1, 7, 3]},
#  {'id': '2000654', 'predict_sentence_index': [2, 1]},
#  {'id': '2000655', 'predict_sentence_index': [2, 1]},
#  {'id': '2000656', 'predict_sentence_index': [3, 6]},
#  {'id': '2000657', 'predict_sentence_index': [6, 0, 1]},
#  {'id': '2000658', 'predict_sentence_index': [4, 7]},
#  {'id': '2000659', 'predict_sentence_index': [2, 1, 10]},
#  {'id': '2000660', 'predict_sentence_index': [0]},
#  {'id': '2000661', 'predict_sentence_index': [6, 7, 0, 8]},
#  {'id': '2000662', 'predict_sentence_index': [10, 2]},
#  {'id': '2000663', 'predict_sentence_index': [1, 9]},
#  {'id': '2000664', 'predict_sentence_index': [0]},
#  {'id': '2000665', 'predict_sentence_index': [8, 7]},
#  {'id': '2000666', 'predict_sentence_index': [7]},
#  {'id': '2000667', 'predict_sentence_index': [5, 1]},
#  {'id': '2000668', 'predict_sentence_index': [6, 3, 0]},
#  {'id': '2000669', 'predict_sentence_index': [6, 3, 8]},
#  {'id': '2000670', 'predict_sentence_index': [7, 1]},
#  {'id': '2000671', 'predict_sentence_index': [4, 0]},
#  {'id': '2000672', 'predict_sentence_index': [4, 2, 3]},
#  {'id': '2000673', 'predict_sentence_index': [4, 0, 2]},
#  {'id': '2000674', 'predict_sentence_index': [2, 0]},
#  {'id': '2000675', 'predict_sentence_index': [3]},
#  {'id': '2000676', 'predict_sentence_index': [4, 6, 7]},
#  {'id': '2000677', 'predict_sentence_index': [2, 3, 4]},
#  {'id': '2000678', 'predict_sentence_index': [3]},
#  {'id': '2000679', 'predict_sentence_index': [1, 0, 5]},
#  {'id': '2000680', 'predict_sentence_index': [1, 0]},
#  {'id': '2000681', 'predict_sentence_index': [4, 5]},
#  {'id': '2000682', 'predict_sentence_index': [4, 3, 2]},
#  {'id': '2000683', 'predict_sentence_index': [1]},
#  {'id': '2000684', 'predict_sentence_index': [4, 3]},
#  {'id': '2000685', 'predict_sentence_index': [3, 5]},
#  {'id': '2000686', 'predict_sentence_index': [9, 2, 4]},
#  {'id': '2000687', 'predict_sentence_index': [1]},
#  {'id': '2000688', 'predict_sentence_index': [1, 4]},
#  {'id': '2000689', 'predict_sentence_index': [3]},
#  {'id': '2000690', 'predict_sentence_index': [2, 7]},
#  {'id': '2000691', 'predict_sentence_index': [0, 4]},
#  {'id': '2000692', 'predict_sentence_index': [5, 2, 6, 4]},
#  {'id': '2000693', 'predict_sentence_index': [1]},
#  {'id': '2000694', 'predict_sentence_index': []},
#  {'id': '2000695', 'predict_sentence_index': [10, 0, 8]},
#  {'id': '2000696', 'predict_sentence_index': [0, 2]},
#  {'id': '2000697', 'predict_sentence_index': [4, 2, 7]},
#  {'id': '2000698', 'predict_sentence_index': [3, 11]},
#  {'id': '2000699', 'predict_sentence_index': [3, 5, 6]},
#  {'id': '2000700', 'predict_sentence_index': [1]},
#  {'id': '2000701', 'predict_sentence_index': [1]},
#  {'id': '2000702', 'predict_sentence_index': [10, 0, 4]},
#  {'id': '2000703', 'predict_sentence_index': [0, 3, 4]},
#  {'id': '2000704', 'predict_sentence_index': [3, 1]},
#  {'id': '2000705', 'predict_sentence_index': [2, 1]},
#  {'id': '2000706', 'predict_sentence_index': [1, 4]},
#  {'id': '2000707', 'predict_sentence_index': [0, 3]},
#  {'id': '2000708', 'predict_sentence_index': [4]},
#  {'id': '2000709', 'predict_sentence_index': [1, 2, 0]},
#  {'id': '2000710', 'predict_sentence_index': [7, 5]},
#  {'id': '2000711', 'predict_sentence_index': [8, 1]},
#  {'id': '2000712', 'predict_sentence_index': [0, 1]},
#  {'id': '2000713', 'predict_sentence_index': [4, 0]},
#  {'id': '2000714', 'predict_sentence_index': [8, 0]},
#  {'id': '2000715', 'predict_sentence_index': [3, 7]},
#  {'id': '2000716', 'predict_sentence_index': [0, 6]},
#  {'id': '2000717', 'predict_sentence_index': [9, 8]},
#  {'id': '2000718', 'predict_sentence_index': [5, 2, 1, 3]},
#  {'id': '2000719', 'predict_sentence_index': [0, 2]},
#  {'id': '2000720', 'predict_sentence_index': [6]},
#  {'id': '2000721', 'predict_sentence_index': [7]},
#  {'id': '2000722', 'predict_sentence_index': [6, 1, 0]},
#  {'id': '2000723', 'predict_sentence_index': [6, 1]},
#  {'id': '2000724', 'predict_sentence_index': [8]},
#  {'id': '2000725', 'predict_sentence_index': [0, 1]},
#  {'id': '2000726', 'predict_sentence_index': [9]},
#  {'id': '2000727', 'predict_sentence_index': [2]},
#  {'id': '2000728', 'predict_sentence_index': [7, 0]},
#  {'id': '2000729', 'predict_sentence_index': [2]},
#  {'id': '2000730', 'predict_sentence_index': [0, 1, 2]},
#  {'id': '2000731', 'predict_sentence_index': [15, 3]},
#  {'id': '2000732', 'predict_sentence_index': [3, 0, 2]},
#  {'id': '2000733', 'predict_sentence_index': [9]},
#  {'id': '2000734', 'predict_sentence_index': [9, 4]},
#  {'id': '2000735', 'predict_sentence_index': [11, 3, 0]},
#  {'id': '2000736', 'predict_sentence_index': [1]},
#  {'id': '2000737', 'predict_sentence_index': [2, 1]},
#  {'id': '2000738', 'predict_sentence_index': [0]},
#  {'id': '2000739', 'predict_sentence_index': [2, 0]},
#  {'id': '2000740', 'predict_sentence_index': [3, 4]},
#  {'id': '2000741', 'predict_sentence_index': [0]},
#  {'id': '2000742', 'predict_sentence_index': [3, 2, 5]},
#  {'id': '2000743', 'predict_sentence_index': [0]},
#  {'id': '2000744', 'predict_sentence_index': [6, 1]},
#  {'id': '2000745', 'predict_sentence_index': [2, 4]},
#  {'id': '2000746', 'predict_sentence_index': [3, 8]},
#  {'id': '2000747', 'predict_sentence_index': [1, 2, 3]},
#  {'id': '2000748', 'predict_sentence_index': [11, 3]},
#  {'id': '2000749', 'predict_sentence_index': [2, 4, 13, 9]},
#  {'id': '2000750', 'predict_sentence_index': [8, 4]},
#  {'id': '2000751', 'predict_sentence_index': [1, 0]},
#  {'id': '2000752', 'predict_sentence_index': [0]},
#  {'id': '2000753', 'predict_sentence_index': [6, 5]},
#  {'id': '2000754', 'predict_sentence_index': [1]},
#  {'id': '2000755', 'predict_sentence_index': [4]},
#  {'id': '2000756', 'predict_sentence_index': [10, 4, 5, 2]},
#  {'id': '2000757', 'predict_sentence_index': [3, 0]},
#  {'id': '2000758', 'predict_sentence_index': [3, 2]},
#  {'id': '2000759', 'predict_sentence_index': [1, 3, 0, 9]},
#  {'id': '2000760', 'predict_sentence_index': [6, 0]},
#  {'id': '2000761', 'predict_sentence_index': [7, 4, 5, 2]},
#  {'id': '2000762', 'predict_sentence_index': [3]},
#  {'id': '2000763', 'predict_sentence_index': [0]},
#  {'id': '2000764', 'predict_sentence_index': [5, 7]},
#  {'id': '2000765', 'predict_sentence_index': [6]},
#  {'id': '2000766', 'predict_sentence_index': [3, 0, 5]},
#  {'id': '2000767', 'predict_sentence_index': [3]},
#  {'id': '2000768', 'predict_sentence_index': [3]},
#  {'id': '2000769', 'predict_sentence_index': [2]},
#  {'id': '2000770', 'predict_sentence_index': [5, 1]},
#  {'id': '2000771', 'predict_sentence_index': [5, 2, 1, 3]},
#  {'id': '2000772', 'predict_sentence_index': [3]},
#  {'id': '2000773', 'predict_sentence_index': [3, 5, 6, 0]},
#  {'id': '2000774', 'predict_sentence_index': [5, 1, 2]},
#  {'id': '2000775', 'predict_sentence_index': [1, 5]},
#  {'id': '2000776', 'predict_sentence_index': [3]},
#  {'id': '2000777', 'predict_sentence_index': [7, 8, 1]},
#  {'id': '2000778', 'predict_sentence_index': [9, 5]},
#  {'id': '2000779', 'predict_sentence_index': [1, 4, 0, 3]},
#  {'id': '2000780', 'predict_sentence_index': [0, 4]},
#  {'id': '2000781', 'predict_sentence_index': [3, 0]},
#  {'id': '2000782', 'predict_sentence_index': [2]},
#  {'id': '2000783', 'predict_sentence_index': [0, 3, 1]},
#  {'id': '2000784', 'predict_sentence_index': [5]},
#  {'id': '2000785', 'predict_sentence_index': [3]},
#  {'id': '2000786', 'predict_sentence_index': []},
#  {'id': '2000787', 'predict_sentence_index': [1, 2]},
#  {'id': '2000788', 'predict_sentence_index': [2, 11, 9]},
#  {'id': '2000789', 'predict_sentence_index': [0, 10]},
#  {'id': '2000790', 'predict_sentence_index': [2, 1]},
#  {'id': '2000791', 'predict_sentence_index': [0]},
#  {'id': '2000792', 'predict_sentence_index': [4, 1, 2, 3]},
#  {'id': '2000793', 'predict_sentence_index': []},
#  {'id': '2000794', 'predict_sentence_index': [1, 5, 8]},
#  {'id': '2000795', 'predict_sentence_index': [1, 6, 7]},
#  {'id': '2000796', 'predict_sentence_index': [3, 4, 2]},
#  {'id': '2000797', 'predict_sentence_index': [4]},
#  {'id': '2000798', 'predict_sentence_index': [7]},
#  {'id': '2000799', 'predict_sentence_index': [2]},
#  {'id': '2000800', 'predict_sentence_index': [1]},
#  {'id': '2000801', 'predict_sentence_index': [1, 2, 3]},
#  {'id': '2000802', 'predict_sentence_index': []},
#  {'id': '2000803', 'predict_sentence_index': [2]},
#  {'id': '2000804', 'predict_sentence_index': [5]},
#  {'id': '2000805', 'predict_sentence_index': [1, 0, 5]},
#  {'id': '2000806', 'predict_sentence_index': [5, 12]},
#  {'id': '2000807', 'predict_sentence_index': [3, 2, 5]},
#  {'id': '2000808', 'predict_sentence_index': [6, 1, 3]},
#  {'id': '2000809', 'predict_sentence_index': [5, 3, 0, 1]},
#  {'id': '2000810', 'predict_sentence_index': [7, 2]},
#  {'id': '2000811', 'predict_sentence_index': [3, 7]},
#  {'id': '2000812', 'predict_sentence_index': [4, 1]},
#  {'id': '2000813', 'predict_sentence_index': [8, 1]},
#  {'id': '2000814', 'predict_sentence_index': [2, 1]},
#  {'id': '2000815', 'predict_sentence_index': [0, 1]},
#  {'id': '2000816', 'predict_sentence_index': [7, 0]},
#  {'id': '2000817', 'predict_sentence_index': [1]},
#  {'id': '2000818', 'predict_sentence_index': [1]},
#  {'id': '2000819', 'predict_sentence_index': [1, 3, 0]},
#  {'id': '2000820', 'predict_sentence_index': [6, 0, 2]},
#  {'id': '2000821', 'predict_sentence_index': [7, 8, 0, 3]},
#  {'id': '2000822', 'predict_sentence_index': [4, 3]},
#  {'id': '2000823', 'predict_sentence_index': [5, 0]},
#  {'id': '2000824', 'predict_sentence_index': [4, 3, 2]},
#  {'id': '2000825', 'predict_sentence_index': [1]},
#  {'id': '2000826', 'predict_sentence_index': [1]},
#  {'id': '2000827', 'predict_sentence_index': [4]},
#  {'id': '2000828', 'predict_sentence_index': [4, 5, 0]},
#  {'id': '2000829', 'predict_sentence_index': [0]},
#  {'id': '2000830', 'predict_sentence_index': [2, 1, 0]},
#  {'id': '2000831', 'predict_sentence_index': [7]},
#  {'id': '2000832', 'predict_sentence_index': [0, 1, 2]},
#  {'id': '2000833', 'predict_sentence_index': [5, 3]},
#  {'id': '2000834', 'predict_sentence_index': [0, 3, 2]},
#  {'id': '2000835', 'predict_sentence_index': [1]},
#  {'id': '2000836', 'predict_sentence_index': [3, 4]},
#  {'id': '2000837', 'predict_sentence_index': [1, 2]},
#  {'id': '2000838', 'predict_sentence_index': [3, 1, 2]},
#  {'id': '2000839', 'predict_sentence_index': [6]},
#  {'id': '2000840', 'predict_sentence_index': [1, 0, 7]},
#  {'id': '2000841', 'predict_sentence_index': [6, 0, 8]},
#  {'id': '2000842', 'predict_sentence_index': []},
#  {'id': '2000843', 'predict_sentence_index': [3]},
#  {'id': '2000844', 'predict_sentence_index': [0]},
#  {'id': '2000845', 'predict_sentence_index': [7, 2, 6]},
#  {'id': '2000846', 'predict_sentence_index': [6]},
#  {'id': '2000847', 'predict_sentence_index': [8, 0]},
#  {'id': '2000848', 'predict_sentence_index': [1]},
#  {'id': '2000849', 'predict_sentence_index': []},
#  {'id': '2000850', 'predict_sentence_index': [1, 0]},
#  {'id': '2000851', 'predict_sentence_index': [6]},
#  {'id': '2000852', 'predict_sentence_index': [0]},
#  {'id': '2000853', 'predict_sentence_index': [0]},
#  {'id': '2000854', 'predict_sentence_index': [0, 4, 3]},
#  {'id': '2000855', 'predict_sentence_index': [3, 2, 5]},
#  {'id': '2000856', 'predict_sentence_index': []},
#  {'id': '2000857', 'predict_sentence_index': []},
#  {'id': '2000858', 'predict_sentence_index': [3]},
#  {'id': '2000859', 'predict_sentence_index': [2, 0]},
#  {'id': '2000860', 'predict_sentence_index': [2]},
#  {'id': '2000861', 'predict_sentence_index': [3]},
#  {'id': '2000862', 'predict_sentence_index': [3, 2, 0, 1]},
#  {'id': '2000863', 'predict_sentence_index': [0, 3]},
#  {'id': '2000864', 'predict_sentence_index': [10, 3, 0]},
#  {'id': '2000865', 'predict_sentence_index': [5]},
#  {'id': '2000866', 'predict_sentence_index': [0, 5]},
#  {'id': '2000867', 'predict_sentence_index': [5, 10, 3, 4]},
#  {'id': '2000868', 'predict_sentence_index': [4, 5, 1]},
#  {'id': '2000869', 'predict_sentence_index': [3, 4, 10]},
#  {'id': '2000870', 'predict_sentence_index': [2, 3]},
#  {'id': '2000871', 'predict_sentence_index': [0, 3]},
#  {'id': '2000872', 'predict_sentence_index': [1]},
#  {'id': '2000873', 'predict_sentence_index': [1, 2]},
#  {'id': '2000874', 'predict_sentence_index': [1]},
#  {'id': '2000875', 'predict_sentence_index': [2, 7]},
#  {'id': '2000876', 'predict_sentence_index': [2]},
#  {'id': '2000877', 'predict_sentence_index': [6, 1, 4, 0]},
#  {'id': '2000878', 'predict_sentence_index': [1]},
#  {'id': '2000879', 'predict_sentence_index': [6]},
#  {'id': '2000880', 'predict_sentence_index': [6, 2, 7]},
#  {'id': '2000881', 'predict_sentence_index': [3, 10, 8]},
#  {'id': '2000882', 'predict_sentence_index': [2]},
#  {'id': '2000883', 'predict_sentence_index': [0]},
#  {'id': '2000884', 'predict_sentence_index': [5, 2, 0, 6]},
#  {'id': '2000885', 'predict_sentence_index': [5, 0, 11]},
#  {'id': '2000886', 'predict_sentence_index': [7, 0, 10]},
#  {'id': '2000887', 'predict_sentence_index': [1, 0]},
#  {'id': '2000888', 'predict_sentence_index': [1, 3]},
#  {'id': '2000889', 'predict_sentence_index': [5, 0, 4]},
#  {'id': '2000890', 'predict_sentence_index': [2, 6]},
#  {'id': '2000891', 'predict_sentence_index': [2, 4]},
#  {'id': '2000892', 'predict_sentence_index': [1]},
#  {'id': '2000893', 'predict_sentence_index': [8, 3]},
#  {'id': '2000894', 'predict_sentence_index': [0]},
#  {'id': '2000895', 'predict_sentence_index': [8, 1]},
#  {'id': '2000896', 'predict_sentence_index': [3]},
#  {'id': '2000897', 'predict_sentence_index': [7, 1]},
#  {'id': '2000898', 'predict_sentence_index': [5, 7, 0]},
#  {'id': '2000899', 'predict_sentence_index': [1, 5, 3]},
#  {'id': '2000900', 'predict_sentence_index': [0, 4]},
#  {'id': '2000901', 'predict_sentence_index': [1, 3]},
#  {'id': '2000902', 'predict_sentence_index': [2, 3]},
#  {'id': '2000903', 'predict_sentence_index': [4, 8, 7, 5]},
#  {'id': '2000904', 'predict_sentence_index': [11, 0, 1, 10]},
#  {'id': '2000905', 'predict_sentence_index': [10]},
#  {'id': '2000906', 'predict_sentence_index': [1, 6, 4]},
#  {'id': '2000907', 'predict_sentence_index': [0, 2]},
#  {'id': '2000908', 'predict_sentence_index': [9]},
#  {'id': '2000909', 'predict_sentence_index': [4, 6]},
#  {'id': '2000910', 'predict_sentence_index': [5, 8, 4]},
#  {'id': '2000911', 'predict_sentence_index': [3, 0]},
#  {'id': '2000912', 'predict_sentence_index': [1, 2]},
#  {'id': '2000913', 'predict_sentence_index': [3, 0, 2]},
#  {'id': '2000914', 'predict_sentence_index': [3]},
#  {'id': '2000915', 'predict_sentence_index': [4]},
#  {'id': '2000916', 'predict_sentence_index': [1]},
#  {'id': '2000917', 'predict_sentence_index': [3]},
#  {'id': '2000918', 'predict_sentence_index': [4]},
#  {'id': '2000919', 'predict_sentence_index': [9, 12]},
#  {'id': '2000920', 'predict_sentence_index': [2, 1]},
#  {'id': '2000921', 'predict_sentence_index': [5, 3]},
#  {'id': '2000922', 'predict_sentence_index': [7, 3, 5]},
#  {'id': '2000923', 'predict_sentence_index': [3]},
#  {'id': '2000924', 'predict_sentence_index': [2, 3]},
#  {'id': '2000925', 'predict_sentence_index': [7, 1, 6]},
#  {'id': '2000926', 'predict_sentence_index': []},
#  {'id': '2000927', 'predict_sentence_index': [6, 7]},
#  {'id': '2000928', 'predict_sentence_index': [5]},
#  {'id': '2000929', 'predict_sentence_index': [6, 3]},
#  {'id': '2000930', 'predict_sentence_index': [3, 1]},
#  {'id': '2000931', 'predict_sentence_index': [1, 0]},
#  {'id': '2000932', 'predict_sentence_index': [4, 1]},
#  {'id': '2000933', 'predict_sentence_index': [2]},
#  {'id': '2000934', 'predict_sentence_index': [8, 0, 5]},
#  {'id': '2000935', 'predict_sentence_index': [6, 1]},
#  {'id': '2000936', 'predict_sentence_index': [1, 2]},
#  {'id': '2000937', 'predict_sentence_index': [7]},
#  {'id': '2000938', 'predict_sentence_index': [2, 0, 1, 5]},
#  {'id': '2000939', 'predict_sentence_index': [4, 1]},
#  {'id': '2000940', 'predict_sentence_index': [5]},
#  {'id': '2000941', 'predict_sentence_index': [3]},
#  {'id': '2000942', 'predict_sentence_index': [4]},
#  {'id': '2000943', 'predict_sentence_index': [0, 1, 2]},
#  {'id': '2000944', 'predict_sentence_index': [9, 3, 1, 7]},
#  {'id': '2000945', 'predict_sentence_index': [1, 7]},
#  {'id': '2000946', 'predict_sentence_index': [0]},
#  {'id': '2000947', 'predict_sentence_index': [2, 7]},
#  {'id': '2000948', 'predict_sentence_index': [5, 3]},
#  {'id': '2000949', 'predict_sentence_index': [1, 0, 4]},
#  {'id': '2000950', 'predict_sentence_index': [3, 2]},
#  {'id': '2000951', 'predict_sentence_index': [8, 1, 2]},
#  {'id': '2000952', 'predict_sentence_index': [3, 0]},
#  {'id': '2000953', 'predict_sentence_index': [1]},
#  {'id': '2000954', 'predict_sentence_index': [3, 1]},
#  {'id': '2000955', 'predict_sentence_index': [2]},
#  {'id': '2000956', 'predict_sentence_index': [0]},
#  {'id': '2000957', 'predict_sentence_index': [8, 6]},
#  {'id': '2000958', 'predict_sentence_index': [2]},
#  {'id': '2000959', 'predict_sentence_index': [6]},
#  {'id': '2000960', 'predict_sentence_index': [4, 3]},
#  {'id': '2000961', 'predict_sentence_index': [0, 4]},
#  {'id': '2000962', 'predict_sentence_index': [0]},
#  {'id': '2000963', 'predict_sentence_index': []},
#  {'id': '2000964', 'predict_sentence_index': [5, 0, 6]},
#  {'id': '2000965', 'predict_sentence_index': [1, 12]},
#  {'id': '2000966', 'predict_sentence_index': [2]},
#  {'id': '2000967', 'predict_sentence_index': [1, 7]},
#  {'id': '2000968', 'predict_sentence_index': [2, 3]},
#  {'id': '2000969', 'predict_sentence_index': [1, 0]},
#  {'id': '2000970', 'predict_sentence_index': [5, 0]},
#  {'id': '2000971', 'predict_sentence_index': [5, 2, 1]},
#  {'id': '2000972', 'predict_sentence_index': [0, 8, 7]},
#  {'id': '2000973', 'predict_sentence_index': [2, 4, 1]},
#  {'id': '2000974', 'predict_sentence_index': [0, 2]},
#  {'id': '2000975', 'predict_sentence_index': [0, 5]},
#  {'id': '2000976', 'predict_sentence_index': [0, 3, 2]},
#  {'id': '2000977', 'predict_sentence_index': [4]},
#  {'id': '2000978', 'predict_sentence_index': [2]},
#  {'id': '2000979', 'predict_sentence_index': [2, 8, 1]},
#  {'id': '2000980', 'predict_sentence_index': [4, 5, 6]},
#  {'id': '2000981', 'predict_sentence_index': [1]},
#  {'id': '2000982', 'predict_sentence_index': [2, 9, 14, 7]},
#  {'id': '2000983', 'predict_sentence_index': [4, 6]},
#  {'id': '2000984', 'predict_sentence_index': [4, 1]},
#  {'id': '2000985', 'predict_sentence_index': [9, 8, 6, 7, 0]},
#  {'id': '2000986', 'predict_sentence_index': [7, 3]},
#  {'id': '2000987', 'predict_sentence_index': [3, 0]},
#  {'id': '2000988', 'predict_sentence_index': [1]},
#  {'id': '2000989', 'predict_sentence_index': [3]},
#  {'id': '2000990', 'predict_sentence_index': [5, 0]},
#  {'id': '2000991', 'predict_sentence_index': [1, 2, 5]},
#  {'id': '2000992', 'predict_sentence_index': [5]},
#  {'id': '2000993', 'predict_sentence_index': [2, 8]},
#  {'id': '2000994', 'predict_sentence_index': [1, 0]},
#  {'id': '2000995', 'predict_sentence_index': [8, 10, 5, 2]},
#  {'id': '2000996', 'predict_sentence_index': [0, 4, 1, 2]},
#  {'id': '2000997', 'predict_sentence_index': [5]},
#  {'id': '2000998', 'predict_sentence_index': [0, 1]},
#  {'id': '2000999', 'predict_sentence_index': [4]},
#  ...]

# %%
result=np.argmax(out.detach().cpu(),2).T.numpy()
        batch_bounds=extract_train.get_bound(i,batch_size)
        for num,bounds in enumerate(batch_bounds):            
            prediction={}
            candidate=[]
            values=[]
            for num2,j in enumerate(bounds):
                sentence_cnt=np.sum(result[num,:][j[0]:j[1]])
                if(sentence_cnt>0):
                    candidate.append(num2)
                    values.append(sentence_cnt)
            values=np.array(values)
            candidate=np.array(candidate)
            prediction['id']=trainData[cnt_train]['id']
            
            #post processing 設定 threshold
            prediction['predict_sentence_index']=[candidate[i] for i in np.argsort(-values)]
            
            cnt_train+=1
            pred_arr.append(prediction)
        progress = ('#' * int(float(i)/len(trainLoader)*40)).ljust(40)
        print('[%03d|%03d] %2.2f sec(s) | %s |' %(epoch,num_epoch,time.time()-epoch_start_time,progress),end='\r',flush=True)
    target_word,prediction_word=predict2sentence(revise_trainData,pred_arr)
    scores_train=calculate_rouge_score(prediction_word,target_word)
